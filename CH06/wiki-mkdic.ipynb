# %%
from gensim.models import word2vec

# %%
model = word2vec.Word2Vec.load('wiki.model')

# %%
model.most_similar(positive=['python', '파이썬'])
# Out:
# [('Tcl', 0.9039197564125061),
#  ('매트랩', 0.8877384662628174),
#  ('MATLAB', 0.8725982904434204),
#  ('액션스크립트', 0.8684271574020386),
#  ('XUL', 0.8669565916061401),
#  ('JSP', 0.8572242856025696),
#  ('Python', 0.8560477495193481),
#  ('IDL', 0.8536214828491211),
#  ('CLR', 0.8535536527633667),
#  ('Perl', 0.8520194292068481)]

# %%
model.most_similar(positive=['아빠', '여성'])
# Out:
# [('엄마', 0.775804340839386),
#  ('중년', 0.7277034521102905),
#  ('여자아이', 0.7210451364517212),
#  ('어른', 0.6959910988807678),
#  ('애인', 0.6835104823112488),
#  ('남성', 0.6820188760757446),
#  ('남자에게', 0.6795535683631897),
#  ('친구', 0.6771835088729858),
#  ('창녀', 0.6706882119178772),
#  ('소녀', 0.666141152381897)]

# %%
model.most_similar(positive=['아빠', '여성'], negative=['남성'])
# Out:
# [('엄마', 0.8517739772796631),
#  ('아저씨', 0.6820619702339172),
#  ('어디가', 0.6796489953994751),
#  ('친구', 0.6589521169662476),
#  ('신혼', 0.6444262266159058),
#  ('괴짜', 0.6426041126251221),
#  ('할머니', 0.6371489763259888),
#  ('아줌마', 0.6364408731460571),
#  ('룸메이트', 0.6234321594238281),
#  ('아내', 0.619864821434021)]

# %%
model['고양이']
# Out:
# array([ -1.15421736e+00,   1.47453928e+00,  -7.97333241e-01,
#         -5.59004545e-01,  -6.63074493e-01,   9.27821093e-04,
#          3.60925913e+00,  -1.52357721e+00,   2.06334496e+00,
#         -1.60574472e+00,   1.53268039e-01,  -2.29279852e+00,
#         -1.01251101e+00,  -1.13544202e+00,   3.35453463e+00,
#         -1.30550778e+00,  -1.16537988e+00,   2.72300869e-01,
#          2.48018217e+00,  -2.53852987e+00,   2.71529332e-02,
#          2.74774456e+00,   1.16185462e+00,   2.93482214e-01,
#          2.44462311e-01,  -4.21865992e-02,   1.46597421e+00,
#         -1.34424198e+00,  -1.73459959e+00,   1.63309908e+00,
#         -1.70248842e+00,  -1.43336117e+00,  -2.80429721e+00,
#          2.43474865e+00,   1.86912581e-01,   1.98837578e+00,
#         -2.14754200e+00,   3.92407089e-01,   1.63187039e+00,
#          1.26348662e+00,  -2.40413523e+00,   3.71543860e+00,
#          6.98261499e-01,  -9.82080460e-01,   3.55798751e-01,
# ...

# %%
model.most_similar(positive=['왕자', '여성'], negative=['남성'])
# Out:
# [('왕녀', 0.7314920425415039),
#  ('여왕', 0.6171671748161316),
#  ('이아손', 0.5895237922668457),
#  ('아들', 0.5856923460960388),
#  ('대왕', 0.5848723649978638),
#  ('왕비', 0.5842419862747192),
#  ('삼촌', 0.5803186893463135),
#  ('왕세자', 0.5697871446609497),
#  ('시녀', 0.5668401718139648),
#  ('공주', 0.5660519599914551)]

# %%
model.most_similar(positive=['서울', '맛집'])
# Out:
# [('강남', 0.6851245164871216),
#  ('인사동', 0.640274167060852),
#  ('서울특별시', 0.6207907199859619),
#  ('연희동', 0.6170412302017212),
#  ('압구정동', 0.6069209575653076),
#  ('서울시', 0.6068366765975952),
#  ('부산', 0.6065454483032227),
#  ('춘천', 0.602898895740509),
#  ('명동', 0.5961471796035767),
#  ('노량진', 0.5898141860961914)]
